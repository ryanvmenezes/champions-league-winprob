# %%
from sklearn.linear_model import LogisticRegression

# %%
import pandas as pd

# %%
matrix = pd.read_csv('minute-matrix.csv')

# %%
matrix.head()
# Out:
#    season  round            tie  made_minute away  t1goal  t2goal  t1awaygoal  \
# 0    2008  first  arsenal-milan          1.0  NaN   False   False       False
# 1    2008  first  arsenal-milan          2.0  NaN   False   False       False
# 2    2008  first  arsenal-milan          3.0  NaN   False   False       False
# 3    2008  first  arsenal-milan          4.0  NaN   False   False       False
# 4    2008  first  arsenal-milan          5.0  NaN   False   False       False
#
#    t2awaygoal  t1goals  t2goals  t1goal_diff  t1awaygoals  t2awaygoals  \
# 0       False        0        0            0            0            0
# 1       False        0        0            0            0            0
# 2       False        0        0            0            0            0
# 3       False        0        0            0            0            0
# 4       False        0        0            0            0            0
#
#    t1awaygoal_diff       t1     t2   winner  t1win
# 0                0  arsenal  milan  arsenal      1
# 1                0  arsenal  milan  arsenal      1
# 2                0  arsenal  milan  arsenal      1
# 3                0  arsenal  milan  arsenal      1
# 4                0  arsenal  milan  arsenal      1

# %%
matrix.tail()
# Out:
#        season  round         tie  made_minute away  t1goal  t2goal  \
# 30236    2019  first  united-psg        180.0  NaN   False   False
# 30237    2019  first  united-psg        181.0  NaN   False   False
# 30238    2019  first  united-psg        182.0  NaN   False   False
# 30239    2019  first  united-psg        183.0  NaN   False   False
# 30240    2019  first  united-psg        184.0    a    True   False
#
#        t1awaygoal  t2awaygoal  t1goals  t2goals  t1goal_diff  t1awaygoals  \
# 30236       False       False        2        3           -1            2
# 30237       False       False        2        3           -1            2
# 30238       False       False        2        3           -1            2
# 30239       False       False        2        3           -1            2
# 30240        True       False        3        3            0            3
#
#        t2awaygoals  t1awaygoal_diff      t1   t2  winner  t1win
# 30236            2                0  united  psg  united      1
# 30237            2                0  united  psg  united      1
# 30238            2                0  united  psg  united      1
# 30239            2                0  united  psg  united      1
# 30240            2                1  united  psg  united      1

# %%
X = matrix[[
    'made_minute',
#     't1goals','t2goals',
    't1goal_diff',
#     't1awaygoals','t2awaygoals',
    't1awaygoal_diff',
#     't1win'
]].values

# %%
y = matrix['t1win'].values

# %%
lrmodel = LogisticRegression(random_state=41, solver='liblinear')

# %%
from sklearn import model_selection

# %%
scores = model_selection.cross_val_score(lrmodel, X, y, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.76 (+/- 0.09)

# %%
model.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=41, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
matrix['probt1win'] = [l[1] for l in model.predict_proba(X)]

# %%
matrix.to_csv('sklearn-pred-prob.csv', index=False)
